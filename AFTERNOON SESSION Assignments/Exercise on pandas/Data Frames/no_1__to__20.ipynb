# %%
# 1
import pandas as pd


file_path = r'AfricaCupofNationsMatches.csv'
df = pd.read_csv(file_path)

print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# 2

import pandas as pd
# 2. Pandas program to get the first 7 rows of your data frame.

# Load the dataset
file_path = r'AfricaCupofNationsMatches.csv'
df = pd.read_csv(file_path)


# Display the first few rows of the dataset
print("First few rows of the dataset: ")
print(df.head(7))



# 3. to select the ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and 
# ‘AwayTeamGoals’ columns from your data frame.

import pandas as pd

# Load the dataset
file_path = r'AfricaCupofNationsMatches.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head(7))
# Out:
# First few rows of the dataset:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
# 3  Select specific columns
selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
print("Selected columns:")
print(selected_columns.head())

# %pip install pandas
# Out:
# Selected columns:
#     HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0     Sudan           Egypt            1.0            2.0
# 1  Ethiopia    South Africa            NaN            NaN
# 2     Egypt        Ethiopia            4.0            0.0
# 3      Egypt       Ethiopia            4.0            0.0
# 4     Sudan        Ethiopia            1.0            0.0

# %%
# select the rows where Egypt appears.
# 4
# Select rows where Egypt appears
egypt_rows = df[(df['HomeTeam'] == 'Egypt') | (df['AwayTeam'] == 'Egypt')]
print("Rows where Egypt appears:")
print(egypt_rows)
print(egypt_rows.count())

# df=['AwayTeam']=df['AwayTeam'].str.strip()
# ethiopia_rows = df[(df['HomeTeam'] == 'Ethiopia') | (df['AwayTeam'] == 'Ethiopia')]
# Out:
# Rows where Egypt appears:
#     Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN      Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN      Egypt     Uganda            2.0            1.0
# 9   1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
# 13  1963  24-Nov-63   NaN      Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN      Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN      Egypt   Ethiopia            3.0            0.0
#
#                 Stage    SpecialWinConditions                 Stadium  \
# 3    Final Tournament                     NaN   Prince Farouk Stadium
# 5    Final Tournament                     NaN   Prince Farouk Stadium
# 7          Semifinals                     NaN  Hailé Sélassié Stadium
# ...

# %%
# 5
#5.to count the number of rows and columns of your data frame.

# Count the number of rows and columns
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 622
# Number of columns: 12

# %%
# 6
# 6.to select the rows where the ‘Attendance’ is missing.

# Select rows where 'Attendance' is missing
missing_attendance_rows = df[df['Attendance'].isna()]
print("Rows where 'Attendance' is missing:")
print(missing_attendance_rows)
# Out:
# Rows where 'Attendance' is missing:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %%
# 7
# 7.to select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.

# Select rows where 'HomeTeamGoals' are between 3 and 6 inclusive
home_goals_between_3_and_6 = df[df['HomeTeamGoals'].between(3, 6)]
print("Rows where 'HomeTeamGoals' are between 3 and 6 inclusive:")
print(home_goals_between_3_and_6)
# Out:
# Rows where 'HomeTeamGoals' are between 3 and 6 inclusive:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
# ...

# %%
# 8
# 8.to change the “AwayTeamGoals” in the 3rd row to 10.

# Change the 'AwayTeamGoals' in the 3rd row to 10
df.at[2, 'AwayTeamGoals'] = 10
print("Updated 3rd row 'AwayTeamGoals' to 10:")
print(df.iloc[2])
# Out:
# Updated 3rd row 'AwayTeamGoals' to 10:
# Year                                 1957
# Date                            16-Feb-57
# Time                                  NaN
# HomeTeam                           Egypt
# AwayTeam                         Ethiopia
# HomeTeamGoals                         4.0
# AwayTeamGoals                        10.0
# Stage                               Final
# SpecialWinConditions                  NaN
# Stadium                 Municipal Stadium
# City                             Khartoum
# Attendance                        30000.0
# Name: 2, dtype: object

# %%
# 9
# to sort the DataFrame first by ‘HomeTeam’ in ascending order,
# then by ‘HomeTeamScores’ in descending order.

# Sort the DataFrame by 'HomeTeam' in ascending order and 'HomeTeamGoals' in descending order
sorted_df = df.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])
print("DataFrame sorted by 'HomeTeam' and 'HomeTeamGoals':")
print(sorted_df.head())
# Out:
# DataFrame sorted by 'HomeTeam' and 'HomeTeamGoals':
#      Year      Date  Time   HomeTeam  AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 205  1990   2-Mar-90   NaN  Algeria    Nigeria            5.0            1.0
# 29   1968  14-Jan-68   NaN  Algeria     Uganda            4.0            0.0
# 135  1980  16-Mar-80   NaN  Algeria     Guinea            3.0            2.0
# 164  1984   5-Mar-84   NaN  Algeria     Malawi            3.0            0.0
# 171  1984  17-Mar-84   NaN  Algeria      Egypt            3.0            1.0
#
#                  Stage SpecialWinConditions                       Stadium  \
# 205            Group A                  NaN          Stade 5 Juillet 1962
# 29             Group A                  NaN        Hailé Sélassié Stadium
# 135            Group B                  NaN               Liberty Stadium
# 164            Group B                  NaN                  Stade Bouaké
# 171  Third place match                  NaN  Stade Félix Houphouët-Boigny
#
# ...

# %%
# 10
# to get list from DataFrame column headers

# Get list of column headers
column_headers = df.columns.tolist()
print("List of DataFrame column headers:")
print(column_headers)
# Out:
# List of DataFrame column headers:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %%
# 11
# to append a desired column to your DataFrame.

# Append a column 'MatchType' to the DataFrame
df['MatchType'] = 'Group Stage'
print("DataFrame with appended 'MatchType' column:")
print()
print(df.head())
# Out:
# DataFrame with appended 'MatchType' column:
#
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2           10.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
#
#                                 SpecialWinConditions                Stadium  \
# 0                                                NaN      Municipal Stadium
# 1  Ethiopia  wins due to disqualification of othe...                    NaN
# ...

# %%
# 12
# 12. to add 2 rows to your DataFrame.

# Add 2 new rows to the DataFrame
new_rows = pd.DataFrame({
    'HomeTeam': ['TeamA', 'TeamB'],
    'AwayTeam': ['TeamC', 'TeamD'],
    'HomeTeamGoals': [2, 3],
    'AwayTeamGoals': [1, 2],
    'Attendance': [15000, 16000],
    'MatchType': ['Group Stage', 'Group Stage']
})
df = pd.concat([df, new_rows], ignore_index=True)
print("DataFrame with 2 new rows added:")
print()
print(df.tail())
# Out:
# DataFrame with 2 new rows added:
#
#        Year                      Date   Time   HomeTeam  AwayTeam  \
# 619  2019.0  14 July 2019 (2019-07-14)  21:00  Algeria    Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00  Tunisia    Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00  Senegal    Algeria
# 622     NaN                        NaN    NaN     TeamA     TeamC
# 623     NaN                        NaN    NaN     TeamB     TeamD
#
#      HomeTeamGoals  AwayTeamGoals                 Stage SpecialWinConditions  \
# 619            2.0            1.0           Semi-finals                  NaN
# 620            0.0            1.0  Third place play-off                  NaN
# 621            0.0            1.0                 Final                  NaN
# 622            2.0            1.0                   NaN                  NaN
# 623            3.0            2.0                   NaN                  NaN
#
#                          Stadium    City  Attendance    MatchType
# ...

# %%
# 13
# 13.to change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame.
# df['AwayTeam'] = df['AwayTeam'].str.strip()
# print(df[df['AwayTeam'] == 'Uganda'].to_string())
# Change 'Uganda' to 'China' in the 'AwayTeam' column
# cleaning data
df['AwayTeam'] = df['AwayTeam'].str.strip()
df['AwayTeam'] = df['AwayTeam'].replace('Uganda', 'China')
print("DataFrame after changing 'Uganda' to 'China' in 'AwayTeam' column:")
print(df.to_string())
# Out:
# DataFrame after changing 'Uganda' to 'China' in 'AwayTeam' column:
#        Year                         Date           Time            HomeTeam             AwayTeam  HomeTeamGoals  AwayTeamGoals                 Stage                                      SpecialWinConditions                         Stadium                  City  Attendance    MatchType
# 0    1957.0                     10-Feb-57            NaN             Sudan                 Egypt            1.0            2.0            Semifinals                                                       NaN               Municipal Stadium              Khartoum     30000.0  Group Stage
# 1    1957.0                     10-Feb-57            NaN          Ethiopia          South Africa            NaN            NaN            Semifinals      Ethiopia  wins due to disqualification of other team                             NaN                   NaN         NaN  Group Stage
# ...

# %%
# 14
# set the index . try out assigning own index to rows #####################
# to reset index in your DataFrame.


# first drop some rows then after call the reset index method

df.dropna(inplace=True)
print(df.head())
print()

# Reset the index of the DataFrame
df_reset_inddex = df.reset_index(drop=True)
print("DataFrame with reset index:")

print(df_reset_inddex.head())
# print(df_reset_inddex.head())
# print(df)
# Out:
#        Year      Date   Time       HomeTeam      AwayTeam  HomeTeamGoals  \
# 315  1998.0  21-Feb-98  17:00      Tunisia   Burkina Faso            1.0
# 316  1998.0  21-Feb-98  20:00  Ivory Coast          Egypt            0.0
# 318  1998.0  25-Feb-98  16:00     DR Congo   South Africa            1.0
# 320  1998.0  27-Feb-98  16:00     DR Congo   Burkina Faso            4.0
# 349  2000.0   7-Feb-00  19:00      Nigeria        Senegal            2.0
#
#      AwayTeamGoals              Stage                 SpecialWinConditions  \
# 315            1.0      Quarterfinals   Burkina Faso win on Penalities 7-8
# 316            0.0      Quarterfinals          Egypt win on Penalities 4-5
# 318            2.0         Semifinals                win after extra time
# 320            4.0  Third place match      DR Congo  win on Penalities 4-1
# 349            1.0      Quarterfinals                win after extra time
#
#               Stadium          City  Attendance    MatchType
# ...

# %%
# 15
# to check whether the ‘Stadium’ column is present in your DataFrame or not.

# Check if 'Stadium' column is present
is_stadium_present = 'Stadium' in df.columns
print(f"Is 'Stadium' column present in the DataFrame? \n{is_stadium_present}")
# Out:
# Is 'Stadium' column present in the DataFrame?
# True

# %%
# 16
#  to convert the datatype of the ‘AwayTeamGoals’. (int to float)

# Convert the datatype of 'AwayTeamGoals' from int to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)
print("Data type of 'AwayTeamGoals' after conversion:")
print(df['AwayTeamGoals'].dtype)
# Out:
# Data type of 'AwayTeamGoals' after conversion:
# float64

# %%
# 17
# to remove the last 10 rows from your DataFrame.

# Remove the last 10 rows from the DataFrame
df_removed_last_10 = df.iloc[:-10]
print("DataFrame after removing the last 10 rows:")
print(df_removed_last_10.tail())
# Out:
# DataFrame after removing the last 10 rows:
#        Year                     Date   Time      HomeTeam       AwayTeam  \
# 609  2019.0  6 July 2019 (2019-07-06)  21:00       Egypt    South Africa
# 610  2019.0  7 July 2019 (2019-07-07)  18:00  Madagascar        DR Congo
# 611  2019.0  7 July 2019 (2019-07-07)  21:00     Algeria          Guinea
# 612  2019.0  8 July 2019 (2019-07-08)  18:00        Mali     Ivory Coast
# 613  2019.0  8 July 2019 (2019-07-08)  21:00       Ghana         Tunisia
#
#      HomeTeamGoals  AwayTeamGoals        Stage  \
# 609            0.0            1.0  Round of 16
# 610            2.0            2.0  Round of 16
# 611            3.0            0.0  Round of 16
# 612            0.0            1.0  Round of 16
# 613            1.0            1.0  Round of 16
#
#                   SpecialWinConditions                      Stadium  \
# 609                                NaN  Cairo International Stadium
# ...

# %%
# 18
# to iterate over rows in your DataFrame.

# Iterate over rows in the DataFrame
print("Iterating over DataFrame rows:")

for index, row in df.iterrows():
    print(f"Index: {index}, HomeTeam: {row['HomeTeam']}, AwayTeam: {row['AwayTeam']}")
# Out:
# Iterating over DataFrame rows:
# Index: 0, HomeTeam: Sudan , AwayTeam: Egypt
# Index: 1, HomeTeam: Ethiopia , AwayTeam: South Africa
# Index: 2, HomeTeam: Egypt , AwayTeam: Ethiopia
# Index: 3, HomeTeam: Egypt, AwayTeam: Ethiopia
# Index: 4, HomeTeam: Sudan , AwayTeam: Ethiopia
# Index: 5, HomeTeam: Egypt, AwayTeam: Sudan
# Index: 6, HomeTeam: Ethiopia , AwayTeam: Tunisia
# Index: 7, HomeTeam: Egypt, AwayTeam: China
# Index: 8, HomeTeam: Tunisia , AwayTeam: China
# Index: 9, HomeTeam: Ethiopia , AwayTeam: Egypt
# Index: 10, HomeTeam: Ghana , AwayTeam: Tunisia
# Index: 11, HomeTeam: Ghana , AwayTeam: Ethiopia
# Index: 12, HomeTeam: Ethiopia , AwayTeam: Tunisia
# Index: 13, HomeTeam: Egypt, AwayTeam: Nigeria
# Index: 14, HomeTeam: Egypt, AwayTeam: Sudan
# Index: 15, HomeTeam: Sudan , AwayTeam: Nigeria
# Index: 16, HomeTeam: Egypt, AwayTeam: Ethiopia
# Index: 17, HomeTeam: Ghana , AwayTeam: Sudan
# Index: 18, HomeTeam: Tunisia , AwayTeam: Ethiopia
# ...

# %%
# 19
#  to change the order of your DataFrame columns.

# Change the order of DataFrame columns
df_reordered = df[['AwayTeam', 'HomeTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Attendance', 'MatchType']]
print("DataFrame with reordered columns:")
print(df_reordered.head())
# Out:
# DataFrame with reordered columns:
#         AwayTeam   HomeTeam  HomeTeamGoals  AwayTeamGoals  Attendance  \
# 0          Egypt     Sudan             1.0            2.0     30000.0
# 1   South Africa  Ethiopia             NaN            NaN         NaN
# 2       Ethiopia     Egypt             4.0           10.0     30000.0
# 3       Ethiopia      Egypt            4.0            0.0     30000.0
# 4       Ethiopia     Sudan             1.0            0.0     20000.0
#
#      MatchType
# 0  Group Stage
# 1  Group Stage
# 2  Group Stage
# 3  Group Stage
# 4  Group Stage

# %%
import pandas as pd

# Load the CSV file

df = pd.read_csv('AfricaCupofNationsMatches.csv')

# Display the first few rows of the DataFrame to understand its structure
# print("Original DataFrame:")
# print(df.head())
# df['HomeTeamGoals'] = df['HomeTeamGoals'].str.strip()
dframe = df[df['HomeTeamGoals'] != 0]


print(dframe.to_string())
# Out:
#      Year                         Date      Time            HomeTeam              AwayTeam  HomeTeamGoals  AwayTeamGoals                 Stage                                      SpecialWinConditions                         Stadium                  City  Attendance
# 0    1957                     10-Feb-57       NaN             Sudan                  Egypt            1.0            2.0            Semifinals                                                       NaN               Municipal Stadium              Khartoum     30000.0
# 1    1957                     10-Feb-57       NaN          Ethiopia           South Africa            NaN            NaN            Semifinals      Ethiopia  wins due to disqualification of other team                             NaN                   NaN         NaN
# ...

# %%
# 20
# to delete DataFrame row(s) whose value is 0 in the ‘HomeTeamGoals’ columns.

# Delete rows where 'HomeTeamGoals' is 0
df_no_zero_home_goals = df[df['HomeTeamGoals'] != 0]
print("DataFrame after deleting rows with 'HomeTeamGoals' equal to 0:")
print(df_no_zero_home_goals)
# Out:
# DataFrame after deleting rows with 'HomeTeamGoals' equal to 0:
#      Year                      Date   Time       HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN        Sudan           Egypt
# 1    1957                  10-Feb-57    NaN     Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN        Egypt        Ethiopia
# 3    1959                  22-May-59    NaN         Egypt       Ethiopia
# 4    1959                  25-May-59    NaN        Sudan        Ethiopia
# ..    ...                        ...    ...           ...            ...
# 614  2019  10 July 2019 (2019-07-10)  18:00      Senegal           Benin
# 615  2019  10 July 2019 (2019-07-10)  21:00      Nigeria    South Africa
# 616  2019  11 July 2019 (2019-07-11)  18:00  Ivory Coast         Algeria
# 618  2019  14 July 2019 (2019-07-14)  18:00      Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00      Algeria         Nigeria
#
# ...
